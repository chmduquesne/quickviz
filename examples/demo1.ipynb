# %%
# %matplotlib inline
from quickviz import visualize as v
from vega_datasets import data
v(data.cars(), method="seaborn")
# Out:
# VBox()
# Output()

# %%
v(data.iris(), method="seaborn")
# Out:
# VBox()
# Output()
