# %%
"""setup"""
import pandas as pd
import pytest
import sys
sys.path.append('../..')
from quickviz import visualize as v
from vega_datasets import data

# %%
"""test_plot"""
df = data.cars()
plot = v(df, method="seaborn")
plot.load({'plot': 'boxplot',
 'kwargs': {'x': 'Origin', 'y': 'Miles_per_Gallon', 'notch': True}})
plot.auto_update.value = True
# Out:
# VBox()
# Output()

# %%
"""test_save"""
plot.save()
# Out:
# {'plot': 'boxplot',
#  'kwargs': {'x': 'Origin', 'y': 'Miles_per_Gallon', 'notch': True}}
