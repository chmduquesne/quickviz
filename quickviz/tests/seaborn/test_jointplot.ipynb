# %%
"""setup"""
import pandas as pd
import pytest
import sys
sys.path.append('../..')
from quickviz import visualize as v
from vega_datasets import data

# %%
"""test_plot"""
df = data.iris()
plot = v(df, method="seaborn")
plot.load({'plot': 'jointplot', 'kwargs': {'x': 'petalWidth', 'y': 'petalLength'}})
plot.auto_update.value = True
# Out:
# VBox()
# Output()

# %%
"""test_save"""
plot.save()
# Out:
# {'plot': 'jointplot', 'kwargs': {'x': 'petalWidth', 'y': 'petalLength'}}
